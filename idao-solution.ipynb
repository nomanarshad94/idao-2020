# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

train = pd.read_csv("../input/idao-dataset/train.csv")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train['x_sim'],train['x'], test_size=0.33, random_state=42)

# %%
train.head()

# %%
#Validation function
n_folds = 2

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, X_train.values.reshape(-1,1), y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
#required libraries
# from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.kernel_ridge import KernelRidge
# from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
# import xgboost as xgb
# import lightgbm as lgb

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

# %%
score = rmsle_cv(KRR)
print("\KernelRidge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %%
# result.to_csv('E:/Idao world contest/IDAO 2020/submit.csv',index=False)

# %%
from sklearn.linear_model import LinearRegression

# %%
x_model = LinearRegression()
vx_model = LinearRegression()
y_model = LinearRegression()
vy_model = LinearRegression()
z_model = LinearRegression()
vz_model = LinearRegression()

# %%
# model.fit(X_train.values.reshape(-1,1), y_train)
x_model.fit(train['x_sim'].values.reshape(-1,1), train['x'])
vx_model.fit(train['Vx_sim'].values.reshape(-1,1), train['Vx'])
y_model.fit(train['y_sim'].values.reshape(-1,1), train['y'])
vy_model.fit(train['Vy_sim'].values.reshape(-1,1), train['Vy'])
z_model.fit(train['z_sim'].values.reshape(-1,1), train['z'])
vz_model.fit(train['Vz_sim'].values.reshape(-1,1), train['Vz'])

# %%
models=[x_model,y_model,z_model,vx_model,vy_model,vz_model]
feat=['x_sim','y_sim','z_sim','Vx_sim','Vy_sim','Vz_sim']
labels=['x','y','z','Vx','Vy','Vz']

# %%
for i,m in enumerate(models):
    print(m.score(train[feat[i]].values.reshape(-1,1), train[labels[i]]))

# %%
for i in models:
    print('intercept:', i.intercept_)
    print('slope:', i.coef_)

# %%
# r_sq = model.score(X_train.values.reshape(-1,1), y_train)
r_sq = model.score(train['x_sim'].values.reshape(-1,1), train['x'])

print('coefficient of determination:', r_sq)

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)

# %%
output = pd.read_csv("../input/track-1-idao/submission.csv")
output.head()

# %%
for i,m in enumerate(models):
    output[labels[i]]=m.predict(output[labels[i]].values.reshape(-1,1))

# %%
output.head()

# %%
output.to_csv("submission.csv",index=False)

# %%
test = pd.read_csv("../input/track-1-idao/test.csv")
test.head()

# %%
y_pred = model.predict(X_test.values.reshape(-1,1))

# y_pred = x_model.predict(test['x_sim'].values.reshape(-1,1))

# %%
# %matplotlib inline
plt.plot(y_pred)
plt.show()
#y_test)

# %%
plt.plot(y_test)
plt.show()
#y_test)

# %%
print(len(y_pred),len(y_test))

# %%
plt.rcParams['agg.path.chunksize'] = 10000

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
transformer = PolynomialFeatures(degree=3, include_bias=False)

# %%
x_ = transformer.fit_transform(train['Vx_sim'].values.reshape(-1,1))

# %%
print(100*(1-(smape(output['Vx'],y_x_pred.reshape(-1,1)))))

# %%
test = pd.read_csv("../input/track-1-idao/test.csv")

# y_x_pred=transformer.transform(test['Vx_sim'].values.reshape(-1,1))

# %%
y_x_pred

# %%
plt.plot(train['x'])
plt.show()

# %%
plt.plot(x_)
plt.show()

# %%
model=LinearRegression().fit(X_train.values.reshape(-1,1), y_train)

# %%
y_pred=model.predict(X_test.values.reshape(-1,1))

# %%
def smape(satellite_predicted_values, satellite_true_values): 
    # the division, addition and subtraction are pointwise 
    return np.mean(np.abs((satellite_predicted_values - satellite_true_values) 
        / (np.abs(satellite_predicted_values) + np.abs(satellite_true_values))))

# %%
print(100*(1-(smape(y_test,y_pred))))

# %%
len(y_test)

# %%
import numpy as np
import pandas as pd
# from lightgbm import LGBMRegressor

from sklearn.linear_model import LinearRegression
#"../input/track-1-idao/submission.csv"

submission = pd.read_csv("../input/track-1-idao/submission.csv")
train = pd.read_csv("../input/idao-dataset/train.csv")
#training models:
x_model = LinearRegression()
vx_model =LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       #min_data_in_leaf=2,
                                       #min_sum_hessian_in_leaf=11
                                       )
y_model =LinearRegression()
vy_model = LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       #min_data_in_leaf=2,
                                       #min_sum_hessian_in_leaf=11
                                       )
z_model = LinearRegression()
vz_model = LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       #min_data_in_leaf=2,
                                       #min_sum_hessian_in_leaf=11
                                       )
x_model.fit(train['x_sim'].values.reshape(-1,1), train['x'])
vx_model.fit(train['Vx_sim'].values.reshape(-1,1), train['Vx'])
y_model.fit(train['y_sim'].values.reshape(-1,1), train['y'])
vy_model.fit(train['Vy_sim'].values.reshape(-1,1), train['Vy'])
z_model.fit(train['z_sim'].values.reshape(-1,1), train['z'])
vz_model.fit(train['Vz_sim'].values.reshape(-1,1), train['Vz'])
#combining in lists:
model_names=['x_model','y_model','z_model','vx_model','vy_model','vz_model']
models=[x_model,y_model,z_model,vx_model,vy_model,vz_model]
feat=['x_sim','y_sim','z_sim','Vx_sim','Vy_sim','Vz_sim']
labels=['x','y','z','Vx','Vy','Vz']
#Printing scores of training
for i,m in enumerate(models):
    print(m.score(train[feat[i]].values.reshape(-1,1), train[labels[i]]))


# submission = test[["id", "x_sim", "y_sim", "z_sim", "Vx_sim", "Vy_sim", "Vz_sim"]]
# submission.columns = ["id", "x", "y", "z", "Vx", "Vy", "Vz"]

#Prediciting values:
for i,m in enumerate(models):
    submission[labels[i]]=m.predict(submission[labels[i]].values.reshape(-1,1))

# just sending simulated values as the answer
submission.to_csv("submission.csv", index=False)

# %%
import pickle

# %%
for i,n in enumerate(model_names):
    with open(n, 'wb') as pickle_file:
        pickle.dump(models[i],pickle_file)

# %%
from lightgbm import LGBMRegressor
lightgbm = LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       #min_data_in_leaf=2,
                                       #min_sum_hessian_in_leaf=11
                                       )

# %%
lightgbm.fit(train['Vx_sim'].values.reshape(-1,1),train['Vx'])

# %%
llgb_prd=lightgbm.predict(test['Vx_sim'].values.reshape(-1,1))

# %%
submission = pd.read_csv("../input/track-1-idao/submission.csv")

# %%
print(100*(1-(smape(output['Vx'],llgb_prd))))

# %%
len(llgb_prd)

# %%
vz_model.booster_.save_model('vz_model.txt')

# %%
vz_model=lgb.Booster(model_file='vz_model.txt')

# %%
# %%time
vz_model.predict(test['Vx_sim'].values.reshape(-1,1))
y_pred = bst.predict(X_test)

# %%
with open('vx_model', 'rb') as pickle_file:
    model= pickle.load(pickle_file)
# submission[labels[i]]=model.predict(submission[labels[i]].values.reshape(-1,1))

# %%
a=model.predict(test['Vx_sim'].values.reshape(-1,1))

# %%
len(a)
